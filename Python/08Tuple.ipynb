# %% [markdown]
# # Tuple
# -------
#
# 1. Tuple is a collection of Data Type.
# 2. declare - ( )
# 3. Tuple are used to store many values & Different Data Type Values in a single Variable. Based On Index. Index start position is 0
# 4. Tuple are ImMutable(Un Changable)

# %%
userData = (101, 'Ram', 'Male')

print(userData, type(userData))
# Out:
# (101, 'Ram', 'Male') <class 'tuple'>

# %%
print(userData[1])
# Out:
# Ram

# %%
userData[1] = 22
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 userData[1] = 22
#
# TypeError: 'tuple' object does not support item assignment
